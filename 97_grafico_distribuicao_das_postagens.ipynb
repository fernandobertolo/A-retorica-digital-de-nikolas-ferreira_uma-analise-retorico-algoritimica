# %%
# CARREGAR ARQUIVO PICKLE (OBRIGATÓRIO)
# Carrega as principais variáveis já processadas, útil para economizar tempo
import pickle
caminho_arquivo = 'corpora/dados.pickle'
with open(caminho_arquivo, 'rb') as arquivo_entrada:
   transcricoes_dados_dict = pickle.load(arquivo_entrada)
del arquivo_entrada, caminho_arquivo

# %%
from funcoes_de_analise.grafico_distribuicao_de_um_termo import grafico_distribuicao_de_um_termo


# Exemplo de uso
lista_termos = ["lula", "esquerda", "homem", "mulher"]
lista_textos = [t["transcricao"] for t in transcricoes_dados_dict]
grafico_distribuicao_de_um_termo(lista_termos, lista_textos, lemma=False)
# Out:
# Processando textos: 99.4% concluído [472/475]
# Concluído. Processando gráfico...
